# %%
import pandas as pd

# %%
outputpath = '/Users/noahsuskin/desktop/Rutgers_DataScience_hw/API-Challenge/WeatherPy/output_data/clean_city_data.csv'
df = pd.read_csv(outputpath)
df.head()
# Out:
#    Unnamed: 0           City  Latitude  Longitude  Max Temp  Humidity  \
# 0           0       Berlevåg     70.86      29.09      50.0        66
# 1           1        Ushuaia    -54.80     -68.30      33.8        86
# 2           2        Rikitea    -23.12    -134.97      75.6        80
# 3           3  Mar del Plata    -38.00     -57.56      62.6        45
# 4           4        Mataura    -46.19     168.86      39.0        90
#
#    Cloudiness  Wind Speed Country        Date
# 0          64       23.04      NO  1591991156
# 1          75       24.16      AR  1591991156
# 2          11       19.93      PF  1591991156
# 3          11       10.29      AR  1591990823
# 4          27        5.01      NZ  1591991157

# %%
col = df.columns[0]

# %%
df = df.drop(col, axis=1)
df.head()
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0       Berlevåg     70.86      29.09      50.0        66          64
# 1        Ushuaia    -54.80     -68.30      33.8        86          75
# 2        Rikitea    -23.12    -134.97      75.6        80          11
# 3  Mar del Plata    -38.00     -57.56      62.6        45          11
# 4        Mataura    -46.19     168.86      39.0        90          27
#
#    Wind Speed Country        Date
# 0       23.04      NO  1591991156
# 1       24.16      AR  1591991156
# 2       19.93      PF  1591991156
# 3       10.29      AR  1591990823
# 4        5.01      NZ  1591991157

# %%
outputpath2 = '/Users/noahsuskin/desktop/Rutgers_DataScience_hw/API-Challenge/WeatherPy/output_data/clean_city_data.html'

df.to_html(outputpath2)
